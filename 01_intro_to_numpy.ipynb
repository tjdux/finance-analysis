# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdux/finance-analysis/blob/main/01_intro_to_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Numpy 소개

# %%
# print() 없이 모든 값의 결과를 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np

# %% [markdown]
# ### ndarray dtype

# %%
a = np.array([1, 2, 3])
a
type(a)
a[0]
# Out:
# array([1, 2, 3])
# numpy.ndarray
# np.int64(1)

# %% [markdown]
# ### universal function

# %%
a = [1, 2, 3]
b = [4, 5, 6]

new_list = []
for e1, e2 in zip(a, b):
  new_list.append(e1+e2)

new_list
# Out:
# [5, 7, 9]

# %%
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

a + b #길이가 길어도 근사적으로 O(1)이 걸린다
# Out:
# array([5, 7, 9])

# %%
a = np.array([
    [1, 2],
    [3, 4]
])

a[0][1]
# Out:
# np.int64(2)
